# %% [markdown]
# variable

# %%
age = 28

# %%
age
# Out:
# 28

# %%
name="Amrutha"

# %%
name
# Out:
# 'Amrutha'

# %%
price=18.98

# %%
price
# Out:
# 18.98

# %%
is_active=True
is_active
# Out:
# True

# %%
x=10
print(x)
# Out:
# 10

# %%
a=10
b=10
c=a+b
print(c)
# Out:
# 20

# %%
firstname="Amrutha"
lastname="thalla"
fullname=firstname+" "+lastname
print(fullname)
# Out:
# Amrutha thalla

# %%
length=10
width=10
area=length*width
area
# Out:
# 100

# %%
print(3 ** 2)
# Out:
# 9

# %% [markdown]
# python variables

# %%
first_name = 'Amrutha'
last_name = 'Thalla'
country = 'HYD'
city = 'TELENGANA'
age = 40000
is_married = True
skills = ['HTML', 'CSS', 'JS', 'React', 'Python']
person_info = {
    'firstname':'Tanya', 
    'lastname':'Reddy', 
    'country':'USA',
    'city':'chicago'
    }

print('First name:', first_name)
print('First name length:',len(first_name))
print('Last name: ', last_name)
print('Last name length: ',len(last_name))
print('Country: ', country)
print('City: ', city)
print('Age: ', age)
print('Married: ', is_married)
print('Skills: ', skills)
print('Person information: ', person_info)
# Out:
# First name: Amrutha
# First name length: 7
# Last name:  Thalla
# Last name length:  6
# Country:  HYD
# City:  TELENGANA
# Age:  40000
# Married:  True
# Skills:  ['HTML', 'CSS', 'JS', 'React', 'Python']
# Person information:  {'firstname': 'Tanya', 'lastname': 'Reddy', 'country': 'USA', 'city': 'chicago'}

# %%
first_name, last_name, country, age, is_married = 'amrutha', 'thalla', 'india', 28, True

print(first_name, last_name, country, age, is_married)
print('First name:', first_name)
print('Last name: ', last_name)
print('Country: ', country)
print('Age: ', age)
print('Married: ', is_married)
# Out:
# amrutha thalla india 28 True
# First name: amrutha
# Last name:  thalla
# Country:  india
# Age:  28
# Married:  True

# %% [markdown]
# strings practice

# %%
letter='A'
print(letter)
greeting='hello everyone'
print(greeting)
print(len(greeting))
multiline_string = '''I am a teacher and enjoy teaching.
I didn't find anything as rewarding as empowering people.
That is why I created 30 days of python.'''
print(multiline_string)
# Out:
# A
# hello everyone
# 14
# I am a teacher and enjoy teaching.
# I didn't find anything as rewarding as empowering people.
# That is why I created 30 days of python.

# %%
first_name = 'Amrutha'
last_name = 'Thalla'
space = ' '
full_name = first_name  +  space + last_name
print(full_name) 
print(len(first_name)) 
print(len(last_name))   
print(len(first_name) > len(last_name)) 
print(len(full_name))
# Out:
# Amrutha Thalla
# 7
# 6
# True
# 14

# %%
language = 'DataScience'
a,b,c,d,e,f,g,h,i,j,k = language 
print(a) 
print(b) 
print(c)  
print(d) 
print(e) 
print(f)
print(g)
print(h)
print(i)
print(j)
print(k)
# Out:
# D
# a
# t
# a
# S
# c
# i
# e
# n
# c
# e

# %%
language = 'DataScience'
last_letter = language[-3:]
print(last_letter)
pto = language[0:8:2] 
print(pto)
# Out:
# nce
# DtSi

# %%
print('I hope every one enjoying the python challenge.\nDo you ?') # line break
print('Days\tTopics\tExercises')
print('Day 1\t3\t5')
print('Day 2\t3\t5')
print('Day 3\t3\t5')
print('Day 4\t3\t5')
print('This is a back slash  symbol (\\)') 
print('In every programming language it starts with \"Hello, World!\"')
# Out:
# I hope every one enjoying the python challenge.
# Do you ?
# Days	Topics	Exercises
# Day 1	3	5
# Day 2	3	5
# Day 3	3	5
# Day 4	3	5
# This is a back slash  symbol (\)
# In every programming language it starts with "Hello, World!"

# %%
challenge = 'training of python'
print(challenge.capitalize())
# Out:
# Training of python

# %%
challenge = 'training of python'
print(challenge.count('y')) # 3
print(challenge.count('y', 7, 14)) # 1
print(challenge.count('th')) # 2`
# Out:
# 1
# 1
# 1

# %% [markdown]
# string indexing

# %%
str="hello python"
str
# Out:
# 'hello python'

# %%
str[0]
# Out:
# 'h'

# %%
str[-1]
# Out:
# 'n'

# %% [markdown]
# string slicing

# %%
str
# Out:
# 'hello python'

# %%
str[0:5]
# Out:
# 'hello'

# %%
str[6:12]
# Out:
# 'python'

# %%
str[1:12:2]
# Out:
# 'el yhn'

# %%
str[::-2]
# Out:
# 'nhy le'

# %%
str[::-1]
# Out:
# 'nohtyp olleh'

# %% [markdown]
# data structures

# %%
l=[]

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)

# %%
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)

# %%
l
# Out:
# [10, 20, 30, 40]

# %%
len(l)
# Out:
# 4

# %%
l
# Out:
# [10, 20, 30, 40]

# %%
l1=l.copy()
l1
# Out:
# [10, 20, 30, 40]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40]

# %%
l==l1
# Out:
# True

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40]
# [10, 20, 30, 40]

# %%
l1.append('nit')
l1.append(True)
l1.append(1+2j)
l1.append(2.3)

# %%
l1
# Out:
# [10, 20, 30, 40, 'nit', True, (1+2j), 2.3]

# %%
l=l1.copy()

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 'nit', True, (1+2j), 2.3]
# [10, 20, 30, 40, 'nit', True, (1+2j), 2.3]

# %%
l1.clear()

# %%
l1
# Out:
# []

# %%
l.append(20)
l
# Out:
# [10, 20, 30, 40, 'nit', True, (1+2j), 2.3, 20]

# %%
l1
# Out:
# []

# %%
l2=[]
l2.append('nit')
l2.append(True)
l2.append(1+2j)
l2.append(2.3)

# %%
l=l1.copy

# %%
print(l)
print(l1)
print(l2)
# Out:
# <built-in method copy of list object at 0x0000017B34E16540>
# []
# ['nit', True, (1+2j), 2.3]

# %%
l=[]
l
# Out:
# []

# %%
print(l)
print(l1)
print(l2)
# Out:
# []
# []
# ['nit', True, (1+2j), 2.3]

# %%
l2.count(True)
# Out:
# 1

# %%
l2[::-1]
# Out:
# [2.3, (1+2j), True, 'nit']

# %%
l2[::2]
# Out:
# ['nit', (1+2j)]

# %%
l2
# Out:
# ['nit', True, (1+2j), 2.3]

# %%
l
l1
l2
# Out:
# ['nit', True, (1+2j), 2.3]

# %%
l
# Out:
# []

# %%
l1
# Out:
# []

# %%
l2
# Out:
# ['nit', True, (1+2j), 2.3]

# %%
l.append(20)
l.append(30)
l.append(40)

# %%
l1 = ['one','two' , "three",'four','five','six']

# %%
print(l)
print(l1)
print(l2)
# Out:
# [20, 30, 40]
# ['one', 'two', 'three', 'four', 'five', 'six']
# ['nit', True, (1+2j), 2.3]

# %%
l[2]
# Out:
# 40

# %%
l1[0][1]
# Out:
# 'n'

# %%
l2[-1]
# Out:
# 2.3

# %%
l2[0:3]
# Out:
# ['nit', True, (1+2j)]

# %%
l1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six']

# %%
l1[:-3]
# Out:
# ['one', 'two', 'three']

# %%
l1[-1:]
# Out:
# ['six']

# %%
l1
# Out:
# ['one', 'two', 'three', 'four', 'five', 'six']

# %%
l1.pop()
# Out:
# 'six'

# %%
l1
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
l4=l1+l2

# %%
l4
# Out:
# ['one', 'two', 'three', 'four', 'five', 'nit', True, (1+2j), 2.3]

# %%
'two' in l4
# Out:
# True

# %%
if 'five' in l4:
    print('five is present in the list')
else:
    print('five is not present in the list')
# Out:
# five is present in the list

# %%
l4
# Out:
# ['one', 'two', 'three', 'four', 'five', 'nit', True, (1+2j), 2.3]

# %%
l4.reverse()

# %%
l4
# Out:
# [2.3, (1+2j), True, 'nit', 'five', 'four', 'three', 'two', 'one']

# %%
l5=[37,73,14,52,73,46,72]

# %%
l5
# Out:
# [37, 73, 14, 52, 73, 46, 72]

# %%
l5.sort()
l5
# Out:
# [14, 37, 46, 52, 72, 73, 73]

# %%
l5.count(73)
# Out:
# 2

# %%
l5
# Out:
# [14, 37, 46, 52, 72, 73, 73]

# %%
l5.sort(reverse=True)
l5
# Out:
# [73, 73, 72, 52, 46, 37, 14]

# %%
l4
# Out:
# [2.3, (1+2j), True, 'nit', 'five', 'four', 'three', 'two', 'one']

# %%
for i in l4:
    print(i)
# Out:
# 2.3
# (1+2j)
# True
# nit
# five
# four
# three
# two
# one

# %% [markdown]
# Tuple

# %%
tuple = ()

# %%
tuple = (12,43,24,53,45,74,86)

# %%
tuple[-1]
# Out:
# 86

# %%
tuple[:]
# Out:
# (12, 43, 24, 53, 45, 74, 86)

# %%
tuple[:6]
# Out:
# (12, 43, 24, 53, 45, 74)

# %%
tuple[-3:]
# Out:
# (45, 74, 86)

# %%
24 in tuple
# Out:
# True

# %%
tuple.index(43)
# Out:
# 1

# %%
tuple.count(12)
# Out:
# 1

# %%
sorted(tuple)
# Out:
# [12, 24, 43, 45, 53, 74, 86]

# %%
sorted(tuple, reverse=True)
# Out:
# [86, 74, 53, 45, 43, 24, 12]
